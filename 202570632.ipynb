# %%
chrs=['a','b','c','d','e']
nums=[1,2,3,4,5]
prices= [1000, 2500, 3000, 1500, 5000]

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
chrs
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
prices
# Out:
# [1000, 2500, 3000, 1500, 5000]

# %%
for i in range(len(nums)):
  nums[i]=nums[i]*10

# %%
nums
# Out:
# [10, 20, 30, 40, 50]

# %%
books=[]

# %%
books.append('파이썬')

# %%
books.append('C')

# %%
books.append('자바')

# %%
books
# Out:
# ['파이썬', 'C', '자바']

# %%
books.insert(2,'GO')

# %%
books
# Out:
# ['파이썬', 'C', 'GO', '자바']

# %%
books.extend({'C++','Pascal'})

# %%
books
# Out:
# ['파이썬', 'C', 'GO', '자바', 'C++', 'Pascal']

# %%
books.pop()
# Out:
# 'Pascal'

# %%
books.remove('C')

# %%
books
# Out:
# ['파이썬', 'GO', '자바', 'C++']

# %%
books.clear()

# %%
books
# Out:
# []

# %%
nums.reverse()

# %%
books
# Out:
# []

# %%
nums
# Out:
# [50, 40, 30, 20, 10]

# %%
nums.sort(reverse=True)

# %%
nums
# Out:
# [50, 40, 30, 20, 10]

# %%
books=['파이썬', 'C', 'GO', '자바', 'C++', 'Pascal']

# %%
books
# Out:
# ['파이썬', 'C', 'GO', '자바', 'C++', 'Pascal']

# %%
'자바' in books
# Out:
# True

# %%
'java' in books
# Out:
# False

# %%
import random
random.choice(books)
# Out:
# 'Pascal'

# %%
max(prices)
# Out:
# 5000

# %%
sum(prices)
# Out:
# 13000

# %%
prices
# Out:
# [1000, 2500, 3000, 1500, 5000]

# %%
total=()
for i in range(len(prices)):
  total+=prices[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-29544686.py in <cell line: 0>()
#       1 total=()
#       2 for i in range(len(prices)):
# ----> 3   total+=prices[i]
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
dynasties
# Out:
# ['태조',
#  '정종',
#  '태종',
#  '세종',
#  '문종',
#  '단종',
#  '세조',
#  '예종',
#  '성종',
#  '연산군',
#  '중종',
#  '인종',
#  '명종',
#  '선조',
#  '광해군',
#  '인조',
#  '효종',
#  '현종',
#  '숙종',
#  '경종',
#  '영조',
#  '정조',
#  '순조',
#  '헌종',
#  '철종',
#  '고종',
#  '순종']

# %%
for i in range(len(dynasties)):
  print(f"{i+1}대{dynasties[i]}")
# Out:
# 1대태조
# 2대정종
# 3대태종
# 4대세종
# 5대문종
# 6대단종
# 7대세조
# 8대예종
# 9대성종
# 10대연산군
# 11대중종
# 12대인종
# 13대명종
# 14대선조
# 15대광해군
# 16대인조
# 17대효종
# 18대현종
# 19대숙종
# 20대경종
# 21대영조
# 22대정조
# 23대순조
# 24대헌종
# 25대철종
# 26대고종
# 27대순종

# %%
char1='한글\n사용법'

# %%
char1
# Out:
# '한글\n사용법'

# %%
'Python'.lower()
# Out:
# 'python'

# %%
ans=input("순번 또는 왕의 이름을 입력")
if ans.isdigit():
   print("숫자")
else:
   print("문자")
# Out:
# 순번 또는 왕의 이름을 입력11
# 숫자

# %%
ans=input("순번 또는 왕의 이름을 입력")
if ans.isdigit():
  i=int(ans)
   print(dynasties[i-1])
else:
  print(dynasties.index(ans)+1)
# Out:
# 순번 또는 왕의 이름을 입력순종
# 27

# %%
coffe={'아메리카노':2000,'라떼':3000,'녹차':2500}

# %%
for k in coffe:
  print(k,coffe[k])
# Out:
# 아메리카노 2000
# 라떼 3000
# 녹차 2500

# %%
for k,v in coffe.items():
  print(k,v)
# Out:
# 아메리카노 2000
# 라떼 3000
# 녹차 2500

# %%
score={'홍길동':100,'이순신':90,'강감찬':80}

# %%
# Out:
#   File "/tmp/ipython-input-97486606.py", line 2
#     print(f"{i+1{score[i]}")
#                           ^
# SyntaxError: f-string: expecting '}'
